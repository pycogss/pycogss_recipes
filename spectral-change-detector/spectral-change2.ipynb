# %%
import ee
import geemap

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from osgeo import gdal

from mpl_toolkits.mplot3d import Axes3D
import geemap.colormaps as cm

import seaborn as sns
import geopandas as gpd

import datetime

# %%
try:
    ee.Initialize()
except: 
    ee.Authenticate()
    ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Spectral Change
#
# This notebook utilizes Google Earth Engine and Sentinel-2 imagery to view trends in spectral indices over time. The temporal trends can be inter-year (over many years) or intrayear (within one year). Additionally, you can calculate the "trend of the trend" to evaluate the rate at which spectral change is occuring.
#
# Index data can also be compared to climate trends using data from the ERA5 Land Daily dataset.
#
# You may also perform an unsupervised KMeans cluster on the different spectral trends.

# %% [markdown]
# # Functions

# %%
def maskS2clouds(image):
    """ Mask cloud and cirrus pixels from Sentinel-2 imagery using QA60 band.

        Parameters:
        image (Image): A single Image in an ImageCollection or standalone Image

        Returns:
        Image with masked features removed and original metadata

    """
    qa = image.select('QA60')

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0) \
        .And(qa.bitwiseAnd(cirrusBitMask).eq(0)) # performs bitwise AND operation between QA60 band and cloud bitmask

    return image.updateMask(mask) \
        .divide(10000) \
        .copyProperties(image, ['system:time_start']) 

def maskWater(image):
    ''' Mask out water using MODIS data.
    
        Define waterMask prior to running.

        Returns: 
        Image with pixels where water_mask < 1. '''
    
    return image.updateMask(waterMask.select('water_mask').lt(1))


def maskS2snow(image):
    ''' Mask snow from Sentinel-2 imagery with MSK_SNWPRB (snow probability mask).

        Returns: 
        Image with pixels where MSK_SNWPRB < 0.9%. '''
    
    mask = image.select('MSK_SNWPRB').lt(0.009)
    
    return image.updateMask(mask).copyProperties(image, ['system:time_start'])

def maskWhite(image):
    ''' Masks white pixels to ensure all cloudy or snowy pixels are removed.

        Returns: 
        Image with pixels where grayscale is greater than or equal to 2000 are removed. '''

    # convert RGB values to grayscale
    grayscale = image.expression(
            '(.3 * 1e4 * R) + (.59 * 1e4 * G) + (.11 * 1e4 * B)', {
            'R': image.select('B4'),
            'G': image.select('B3'),
            'B': image.select('B2')
        })
    
    white_mask = grayscale.lte(2000)

    return image.updateMask(white_mask).copyProperties(image,['system:time_start'])

def clp(image):
    '''Clips a single Image to a region of interest'''
    return image.clip(aoi)

def addNDVI(image):
    '''Adds S2's NDVI band to each image (in an ImageCollection)'''
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    return image.addBands(ndvi).copyProperties(image, ['system:time_start'])

def annual_images(y):
    ''' Filters an image collection for a specific year (y) and date range (start and end month).
        Applies the chosen analysis (mean, min, max, or median) to calculate the statistics for the images in that year.
        
        Requires:
        index_collection, start_month, end_month, and analysis.
    
        Parameters: 
        y: a given year

        Returns:
        Statistcs over the image within the date range.
    '''
    # filter for given year
    range_year = ee.Filter.calendarRange(y, y, 'year')
    #filter for specified month range
    range_month = ee.Filter.calendarRange(start_month, end_month, 'month')

    # filter image collection by year and month and add a time band
    filtered_dataset = (index_collection
                        .filter(range_year)
                        .filter(range_month)
                        .map(lambda image: image.addBands(image.metadata('system:time_start').divide(3.154e10)))) # Needed for linear regression 
        
    # Print out the number of images in the filtered dataset
    num_images = filtered_dataset.size()
    
    # Choose the reducer based on the chosen analysis
    if analysis == 'mean':
        reducer = ee.Reducer.mean().combine( # calculates average value for each pixel across all images
            reducer2=ee.Reducer.stdDev(), # calculates standard deviation
            sharedInputs=True
        )

    elif analysis == 'min' or analysis == 'max':
        reducer = ee.Reducer.mean().combine( # calculates minimum and maximum values
            reducer2=ee.Reducer.minMax(),#
            sharedInputs=True
        )
    elif analysis == 'median':
        reducer = ee.Reducer.mean().combine( # calculates middle value for each pixel
            reducer2=ee.Reducer.median(),
            sharedInputs=True
        )

    # Use the combined reducer to get the statistics
    stats = filtered_dataset.reduce(reducer)
    return stats.set('year', y).set('num', num_images)
    

def intrayear(index_collection):
    ''' Filter Image Collection within a single year. Used for seasonal (one-year) trends.

        Function is used when start_year = end_year.

        Requires: 
        index_collection, start_month, end_month, start_year, and end_year.

        Parameters: 
        index_collection: an ImageCollection containing images with a chosen index

        Returns:
        filtered_dataset: Filtered Image Collection
    '''
    
    range_year = ee.Filter.calendarRange(start_year, end_year, 'year')
    range_month = ee.Filter.calendarRange(start_month, end_month, 'month')
    
    # add a time band with the year to each image 
    filtered_dataset = (index_collection
                        .filter(range_year)
                        .filter(range_month)
                        .map(lambda image: image.addBands(image.metadata('system:time_start').divide(3.154e10)))) # Needed for linear regression 
    
    num_images = filtered_dataset.size()

    return filtered_dataset.set('year', start_year).set('num', num_images)


def annual_trend(y):
    ''' Calculate temporal trend for an index (NDVI) within a specified date range.
        Applies a linear regression to analyze the trend of changes over time for the chosen index.
        aka the trend of the trend!

        Requires:
        index_collection, start_month, and end_month.
    
        Parameters: 
        y: a given year

        Returns:
        Statistcs over the image within the date range.
    '''
    range_year = ee.Filter.calendarRange(y, y, 'year')
    range_month = ee.Filter.calendarRange(start_month, end_month, 'month')
   
   # add a time band with the year to each image 
    filtered_dataset = (index_collection
                        .filter(range_year)
                        .filter(range_month)
                        .map(lambda image: image.addBands(image.metadata('system:time_start').divide(3.154e10)))) # Needed for linear regression 
    
    # Print out the number of images in the ImageCollection for each year
    num_images = filtered_dataset.size()
    
    # Use the combined reducer to get the statistics
    stats = filtered_dataset.reduce(reducer = ee.Reducer.linearFit())
    return stats.set('year', y).set('num', num_images)

def createTimeBand(image):   
    '''Adds a time band to the image using metadata'''
    return image.addBands(image.metadata('system:time_start').divide(3.154e10))

def meanNDVI(image): 
    ''' Calculates the mean NDVI within a specific region.
        
        Requires:
        ndvi, aoi

        Returns:
        Image with property 'ndvi_mean'. '''
    
    ndvi = image.select('NDVI')
    ndvi_mean = ndvi.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=aoi,
        scale=10
    ).get('NDVI')

    ndvi_mean = ee.Number(ndvi_mean)
    
    return image.set('ndvi_mean', ndvi_mean)

def addElevation(image):
  '''Adds ArcticDEM elevation to each image (in an ImageCollection)'''
  elevation = ee.Image("UMN/PGC/ArcticDEM/V3/2m_mosaic").select('elevation').clip(aoi).rename('ArcticDEM')
  return image.addBands(elevation)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Build collection
#
# ### Define AOI and build image collection. Choose a cell to use HYBAS watershed boundaries, coordinates, or upload a geoJSON.
#
# Option 1: Load the boundary of a wastershed with its level 10 HYBAS_ID

# %%
HYBAS_ID = 8100087910

aoi = ee.FeatureCollection("WWF/HydroSHEDS/v1/Basins/hybas_10").filter(ee.Filter.eq('HYBAS_ID', HYBAS_ID))

long = aoi.geometry().centroid().coordinates().get(0).getInfo()
lat = aoi.geometry().centroid().coordinates().get(1).getInfo()

# %% [markdown]
# Option 2: use coordinates

# %%
lat, long  = (69.5, -143.66) #North Slope AK

aoi_point = ee.Geometry.Point([long, lat])

aoi = aoi_point.buffer(3000).bounds()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Option 3: upload geoJSON from local directory

# %%
aoi = geemap.geojson_to_ee('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/tgc3b-2.geojson')

long = aoi.geometry().centroid().coordinates().get(0).getInfo()
lat = aoi.geometry().centroid().coordinates().get(1).getInfo()

# %% [markdown]
# # Load dataset
#
# Adjust the years and months for the desired time range.
# Adjust CLOUDY_PIXEL_PERCENTAGE for desired cloudiness.

# %%
# Get water mask
waterMask = (
    ee.ImageCollection('MODIS/006/MOD44W') 
    .filter(ee.Filter.date('2015-01-01', '2015-01-02')) 
    .select('water_mask') \
    .first()
)
# Get Sentinel 2 harmonized images
dataset = (
    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
                #  Filter by year
                  .filter(ee.Filter.calendarRange(2019,2024,'year'))
                #  Filter by month
                  .filter(ee.Filter.calendarRange(6,8,'month'))
                #  Pre-filter to get less cloudy granules.
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))
                  .filterBounds(aoi)
                  .map(clp)
                  .map(maskS2clouds)
                  .map(maskS2snow)
                  .map(maskWhite)
                  .map(maskWater)
                  .map(addNDVI)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map(center = (lat, long), zoom = 11)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Do analysis
# select your index and time frame

# %%
# Pick your index
index = 'NDVI'
# Choose 'mean', 'median', 'min', or 'max' for analysis
analysis = 'min'  

# limit beyond your ImageCollection
start_year = 2019
end_year = 2024
start_month = 6
end_month = 8 # you can pick the same start/end month to see that month changes over the years

# image collection with index band
index_collection = dataset.select(index)  

# Generate list of years
years = ee.List.sequence(start_year, end_year)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Skip to different sections to:
# - view spectral trends on the map <br>
# - plot the index values of different regions <br>
# - perform a KMeans cluster

# %% [markdown]
# # View Trend
# ## Choose temporal trend or trend of trend

# %% [markdown]
# Option 1: Temporal trend- change in index over time

# %%
if start_year == end_year:
    intrayear_collection = intrayear(index_collection)

    item = intrayear_collection.getInfo()
    print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

    # Get linear fit to pixelwise trend of annual max NDVI
    trend = intrayear_collection.select(['system:time_start',
                                index
                                ]).reduce(ee.Reducer.linearFit())

else:

    # Map over years to get yearly statistics
    yearwise_ndvi = years.map(annual_images)

    for item in yearwise_ndvi.getInfo():
        print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

        yearCompCol = ee.ImageCollection.fromImages(yearwise_ndvi)

        # Get linear fit to pixelwise trend of annual max NDVI
        trend = yearCompCol.select(['system:time_start_mean',
                                    f'{index}_{analysis}'
                                    ]).reduce(ee.Reducer.linearFit())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Year: 2019 Number of images: 8
# Year: 2020 Number of images: 8
# Year: 2021 Number of images: 3
# Year: 2022 Number of images: 4
# Year: 2023 Number of images: 7
# Year: 2024 Number of images: 13

# %% [markdown]
# Option 2: Trend of the trend- change in seasonal trend over time (skip the above cell)

# %%
# Map over years to get annual trend
yearwise_trend = years.map(annual_trend)

for item in yearwise_trend.getInfo():
    print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

yearCompCol = ee.ImageCollection.fromImages(yearwise_trend)

trend = yearCompCol.reduce(ee.Reducer.linearFit())

# %% [markdown]
# ### Map

# %% [markdown]
# Find the min and max values of the trend, which will be used as the min and max values of the colorbar.

# %%
scale = trend.select('scale')

tMin = scale.reduceRegion(
    reducer=ee.Reducer.min(),
    geometry=aoi,
    scale=500,  # Adjust the scale depending on your resolution
    maxPixels=1e9
).getInfo()

tMax = scale.reduceRegion(
    reducer=ee.Reducer.max(),
    geometry=aoi,
    scale=500,  # Adjust the scale depending on your resolution
    maxPixels=1e9
).getInfo()


# if (0-tMin['scale']) > tMax['scale']:
#     tMax['scale'] = (0 - tMin['scale'])

# elif (0-tMin['scale']) < tMax['scale']:
#     tMin['scale'] = (0 - tMax['scale'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
image_limit = 5

# view RGB
for image_id in intrayear(dataset).aggregate_array("system:index").getInfo()[0:image_limit]:
        image = intrayear(dataset).filterMetadata("system:index", "equals", image_id).first()
        
        image_RGB = image.select('B4', 'B3', 'B2') 
        RGB_vis_params = {'min': 0.0, 'max': 0.3}
        Map.addLayer(image_RGB, RGB_vis_params, ee.Image(image).date().format('yyyy-MM-dd').getInfo(), True)

# view NDVI
# for image_id in intrayear_collection.aggregate_array("system:index").getInfo()[0:image_limit]:
#         image = intrayear_collection.filterMetadata("system:index", "equals", image_id).first()
#         date_string = ee.Image(image).date().format('yyyy-MM-dd').getInfo()

#         Map.addLayer(image.select('NDVI'), {}, f'{date_string}_NDVI', False)

# view trend
Map.addLayer(trend.select('scale'),
              {'min': round(tMin['scale'], 3), 'max': round(tMax['scale'], 3),
             'palette': ['red','white', 'blue']
             },
  'trend')


# add colorbar for trend
Map.add_colorbar_branca(colors=['red', 'white', 'blue'], vmin=round(tMin['scale'], 3), vmax=round(tMax['scale'], 3), layer_name='trend')


Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=478330.0, center=[69.48367351057459, -143.46542125948056], controls=(WidgetControl(options=['positi…

# %% [markdown]
# download trend as TIFF

# %%
geemap.download_ee_image(trend.select('scale'), 'NSlope3_NDVImin.tif', scale=10, region=aoi, crs='EPSG:3995')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# NSlope3_NDVImin.tif: |          | 0.00/5.71M (raw) [  0.0%] in 00:00 (eta:     ?)

# %% [markdown]
# # Compare mean trends of 2 AOIs

# %% [markdown]
# Run the following cell and draw a region of interest on the map. If the image isn't full coverage, toggle on the Esri Worldview basemap.

# %%
# pick the image with the most coverage
image_RGB = dataset.sort('NODATA_PIXEL_PERCENTAGE', False).first().select('B4', 'B3', 'B2')

RGB_vis_params = {'min': 0.0, 'max': 0.3}
Map.addLayer(image_RGB, RGB_vis_params, ee.Image(image_RGB).date().format('yyyy-MM-dd').getInfo(), True)

Map

# %%
aoi = ee.FeatureCollection(Map.draw_features)

# %% [markdown]
# Optional: export polygon as .geojson

# %%
geemap.ee_export_vector(aoi, 'Nslope_norm_slp.geojson')

# %% [markdown]
# ## Begin here if you are using already defined AOIs.
#
# upload an aoi (GeoJSON)

# %%
aoi = geemap.geojson_to_ee('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/Nslope_norm_wt.geojson')

# %% [markdown]
# Calculate mean NDVI of the area for each date and convert to a data frame.

# %%
clp_collection = index_collection.map(clp)

# average NDVI
ndvi_collection = clp_collection.map(meanNDVI)

# Map.addLayer(ndvi_collection.first(), {}, "clip")
# Map

# %% [markdown]
# create dataframe with mean index over the entire aoi for each date

# %%
image_list = ndvi_collection.getInfo()
data = []

# add date and mean NDVI to data frame
for img in image_list['features']:
    properties = img['properties']
    data.append({
            'date': ee.Date(properties['system:time_start']).format('YYYY-MM-dd').getInfo(),
            'ndvi_mean': properties.get('ndvi_mean')
        })
    
df = pd.DataFrame(data, columns=['date', 'ndvi_mean'])

# %%
# save csv 
df.to_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/NSlope_norm_wt.csv')

# %% [markdown]
# Repeat the above cells with a different AOI. Once you have calculated the mean NDVI of your AOIs, you can load the saved CSVs to compare their data.

# %%
# load NDVI values for water track
wt = pd.read_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia/ESiberia_inv_wt.csv')

# load NDVI values for intertrack region
intertrack = pd.read_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia/ESibera_inv_slp.csv')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # plot normal vs inverse greening
# ### load water track and intertrack data above. then save data as inverse or normal greening
# ### repeat for other region
# SKIP next 2 cells unless plotting track:intertrack NDVI ratio (to compare dates)

# %%
inverse = pd.merge(wt, intertrack, on=['date'],  suffixes=('_wt', '_intertrack'))

# %%
normal = pd.merge(wt, intertrack, on=['date'], suffixes=('_wt', '_intertrack'))

# %% [markdown]
# ### plot inverse vs normal greening
# run above cells to extract NDVI values for water track and intertrack regions.
# then, save data as either inverse or normal greening

# %%
inverse = pd.concat([wt, intertrack], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
normal = pd.concat([wt, intertrack], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
wt['region'] = 'track'
intertrack['region'] = 'intertrack'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Run to convert date to datetime, add ordinal date, year, and DOY

# %%
# convert date to datetime
inverse['date'] = pd.to_datetime(inverse['date'])
normal['date'] = pd.to_datetime(normal['date'])

# add ordinal date column to assist with plotting
inverse['date_ordinal'] = inverse['date'].apply(lambda x: x.toordinal())
normal['date_ordinal'] = normal['date'].apply(lambda x: x.toordinal())

inverse['doy'] = inverse['date'].dt.dayofyear
inverse['year'] = inverse['date'].dt.year

normal['doy'] = normal['date'].dt.dayofyear
normal['year'] = normal['date'].dt.year
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### ratio of track to intertrack greeness
#
# need 2 dfs: inverse and normal, where wt and intertrack were joined by date

# %%
# make new column called 'ndvi_ratio' that is track/intertrack
inverse['ndvi_ratio'] = inverse['ndvi_mean_wt'] / inverse['ndvi_mean_intertrack']

normal['ndvi_ratio'] = normal['ndvi_mean_wt'] / normal['ndvi_mean_intertrack']

# %%
fig = plt.figure(figsize=(9, 6))

colors = {
    2019: 'r',
    2020: 'orange',
    2021: 'g',
    2022: 'b',
    2023: 'purple'
}

for year, group in inverse.groupby(by='year'):
    plt.scatter(group['doy'], group['ndvi_ratio'], label=year, color=colors[year], alpha=0.7)

# plt.title('Track/Intertrack Max NDVI of Normal Greening WTs')
plt.xlabel('Day of Year (DOY)')
plt.ylabel('track:intertrack NDVI')
plt.legend()

ymin = np.nanmin(inverse['ndvi_ratio'])
ymax = np.nanmax(inverse['ndvi_ratio'])
plt.ylim(ymin, ymax)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(7, 7))

colors = {
    2019:'r',
    2020:'orange',
    2021:'g',
    2022:'b',
    2023 : 'purple'
}


for year, group in inverse.groupby(by='year'):
    axes[1].scatter(group['doy'], group['ndvi_ratio'], label=year, color=colors[year], alpha=0.7)

for year, group in normal.groupby(by='year'):
    axes[0].scatter(group['doy'], group['ndvi_ratio'], label=year, color=colors[year], alpha=0.7)

axes[0].set_title('Normal Greening Water Track')
axes[0].set_xlabel('Day of Year (DOY)')
axes[0].set_ylabel('Track:Intertrack NDVI')

axes[1].set_title('Inverse Greening Water Track')
axes[1].set_xlabel('Day of Year (DOY)')
axes[1].set_ylabel('Track:Intertrack NDVI')

axes[1].axhline(y=1, color='black', linestyle='--', linewidth=0.8)
axes[0].axhline(y=1, color='black', linestyle='--', linewidth=0.8)

# ymin = np.nanmin(inverse['ndvi_ratio'])
# ymax = np.nanmax(inverse['ndvi_ratio'])
axes[0].set_ylim(0.3,1.5)
axes[1].set_ylim(0.3, 1.5)


handles, labels = axes[0].get_legend_handles_labels()
# fig.legend(handles, labels, title="Year", loc="lower center", ncol=5, bbox_to_anchor=(0.5, -0.07), frameon=True)
fig.legend(handles, labels, title="Year", loc="center right", ncol=1, bbox_to_anchor=(1.13, 0.5), frameon=True)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Simple Plots

# %%
fig, ax = plt.subplots(figsize=(12,4))

inverse[inverse['region'] == 'track'].plot.scatter(x='date', y='ndvi_mean', color='blue', label='Water Track', ax=ax)

inverse[inverse['region'] == 'intertrack'].plot.scatter(x='date', y='ndvi_mean', color='green', label='Intertrack', ax=ax)

plt.xlabel('Date')
plt.ylabel('Mean NDVI')
# plt.title('Mean NDVI in Water Track and Intertrack - Inverse greening')
plt.legend()

plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(9, 6))

colors = {
    2019:'r',
    2020:'orange',
    2021:'g',
    2022:'b',
    2023 : 'purple'
}

for year, group in inverse[inverse['region'] == 'track'].groupby(by='year'):
    group.plot(x='doy', y='ndvi_mean', label=year, color=colors[year], ax=axes[0])

for year, group in normal[normal['region'] == 'track'].groupby(by='year'):
    group.plot(x='doy', y='ndvi_mean', label=year, color=colors[year], ax=axes[1])

axes[1].set_title('Normal Greening')
axes[1].set_xlabel('DOY')
axes[1].set_ylabel('Mean NDVI')
axes[1].legend()

axes[0].set_title('Inverse Greening')
axes[0].set_xlabel('Day of Year (DOY)')
axes[0].set_ylabel('Mean NDVI')
axes[0].legend()

ymin = min(inverse['ndvi_mean'])
ymax = max(inverse['ndvi_mean'])
axes[0].set_ylim(ymin, ymax)
axes[1].set_ylim(ymin, ymax)

fig.tight_layout()

# %% [markdown]
# linear regression plot - plot max NDVI average of just the water track, separated by year

# %%
fig, axes = plt.subplots(2, 1, figsize=(9, 6))

colors = {
    2019:'r',
    2020:'orange',
    2021:'g',
    2022:'b',
    2023 : 'purple'
}

for year, group in inverse[inverse['region'] == 'track'].groupby(by='year'):
    sns.scatterplot(x='doy', y='ndvi_mean', label=year, color=colors[year], data=group, ax=axes[0], legend=False)

sns.regplot(x='doy', y='ndvi_mean', data=inverse[inverse['region'] == 'track'],
            scatter=False, ax=axes[0], color='black', line_kws={'linestyle': '--'}, label='Mean MaxNDVI')

for year, group in normal[normal['region'] == 'track'].groupby(by='year'):
    sns.scatterplot(x='doy', y='ndvi_mean', label=year, color=colors[year], data=group, ax=axes[1], legend = False)

sns.regplot(x='doy', y='ndvi_mean', data=normal[normal['region'] == 'track'],
            scatter=False, ax=axes[1], color='black', line_kws={'linestyle': '--'}, label='Mean MaxNDVI')

axes[1].set_title('Normal Greening Water Track')
axes[1].set_xlabel('Day of Year (DOY)')
axes[1].set_ylabel('MaxNDVI')

axes[0].set_title('Inverse Greening Water Track')
axes[0].set_xlabel('Day of Year (DOY)')
axes[0].set_ylabel('MaxNDVI')

ymin = min(inverse['ndvi_mean'])
ymax = max(inverse['ndvi_mean'])
axes[0].set_ylim(ymin, ymax)
axes[1].set_ylim(ymin, ymax)


handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, title="Year", loc="center right", ncol=1, bbox_to_anchor=(1.2, 0.5), frameon=True)


fig.tight_layout()
plt.show()

# %% [markdown]
# polynomial fit

# %%
fig, axes = plt.subplots(2, 1, figsize=(9, 6))

colors = {
    2019:'r',
    2020:'orange',
    2021:'g',
    2022:'b',
    2023 : 'purple',
    2024 : 'pink'
}

all_doy = np.concatenate([inverse[inverse['region'] == 'track']['doy'], normal[normal['region'] == 'track']['doy']])
all_ndvi_mean = np.concatenate([inverse[inverse['region'] == 'track']['ndvi_mean'], normal[normal['region'] == 'track']['ndvi_mean']])
x_min, x_max = all_doy.min(), all_doy.max()
y_min, y_max = all_ndvi_mean.min(), all_ndvi_mean.max()


for year, group in inverse[inverse['region'] == 'track'].groupby(by='year'):
    sns.scatterplot(x='doy', y='ndvi_mean', label=year, color=colors[year], data=group, ax=axes[0], legend=False)

sns.regplot(x='doy', y='ndvi_mean', data=inverse[inverse['region'] == 'track'],
            scatter=False, ax=axes[0], color='black', line_kws={'linestyle': '--'}, label='Mean MaxNDVI', order = 2)

for year, group in normal[normal['region'] == 'track'].groupby(by='year'):
    sns.scatterplot(x='doy', y='ndvi_mean', label=year, color=colors[year], data=group, ax=axes[1], legend = False)

sns.regplot(x='doy', y='ndvi_mean', data=normal[normal['region'] == 'track'],
            scatter=False, ax=axes[1], color='black', line_kws={'linestyle': '--'}, label='Mean MaxNDVI', order = 2)

axes[1].set_title('Normal Greening Water Track')
axes[1].set_xlabel('Day of Year (DOY)')
axes[1].set_ylabel('MaxNDVI')

axes[0].set_title('Inverse Greening Water Track')
axes[0].set_xlabel('Day of Year (DOY)')
axes[0].set_ylabel('MaxNDVI')

ymin = min(inverse['ndvi_mean'])
ymax = max(inverse['ndvi_mean'])
axes[0].set_ylim(ymin, ymax)
axes[1].set_ylim(ymin, ymax)


handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, title="Year", loc="center right", ncol=1, bbox_to_anchor=(1.2, 0.5), frameon=True)


fig.tight_layout()
plt.show()

# %% [markdown]
# Plot June dates

# %%
June = normal[normal['date'].dt.month == 6]

plt.figure(figsize=(7, 7))

bplot = sns.boxplot(x='region', y='ndvi_mean', data=June, palette = {'track': 'purple', 'intertrack': 'green'}, showfliers = False)
bplot.set_xlabel('Region')
bplot.set_ylabel('June MaxNDVI')
bplot.set_title('Normal Greening')

# %% [markdown]
# # Climate Data

# %%
def select_data(image):
    return image.select(doi)


def mean_temp(image): 
    ''' Calculates the mean temperature within a specific region.
        
        Requires:
        temp_stat, aoi

        Returns:
        Image with property 'temp_aoi_mean'. '''
    
    temp = image.select(temp_stat)
    temp_aoi_mean = temp.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=aoi,
        scale=10
    ).get(temp_stat)

    temp_aoi_mean = ee.Number(temp_aoi_mean)
    
    return image.set('temp_aoi_mean', temp_aoi_mean)

def mean_stat(image): 
    ''' Calculates the mean of a band within a specific region.
        
        Requires:
        band_name

        Returns:
        Image with property band_name+'_aoi_mean' '''
    
    band_data = image.select(band_name)
    band_aoi_mean = band_data.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=aoi,
        scale=10
    ).get(band_name)

    band_aoi_mean = ee.Number(band_aoi_mean)
    
    return image.set(band_name+'_aoi_mean', band_aoi_mean)

# %%
# data of interest from ERA5 Land Daily

doi = ['temperature_2m','temperature_2m_max', 'temperature_2m_min' 'soil_temperature_level_1','snow_cover','volumetric_soil_water_layer_1','sub_surface_runoff_sum' ]

# %%
dataset = (
    ee.ImageCollection("ECMWF/ERA5_LAND/DAILY_AGGR")
                #  Filter by year
                  .filter(ee.Filter.calendarRange(2019,2024,'year'))
                #  Filter by month
                  # .filter(ee.Filter.calendarRange(6,8,'month'))
                  .filterBounds(aoi)
                  .map(clp)
                  .map(select_data)
)

# %% [markdown]
# Create an image collection of temperature data and save in DF.

# %%
# min, max
temp_stat = 'temperature_2m'

# set average temp (from band) over aoi as a property
temp_collection = dataset.map(mean_temp)

temp_features = temp_collection.map(
    lambda image: ee.Feature(None, {
        'date': image.date().format('YYYY-MM-dd'),
        'temp_aoi_mean': image.get('temp_aoi_mean')
    })
).getInfo()

# %%
data = []

# add date and temp_aoi_mean to data frame
for feature in temp_features['features']:
    properties = feature['properties']
    # print(properties)
    data.append({
            'date': properties['date'],
            'temp_aoi_mean': properties['temp_aoi_mean']
        })
    
df = pd.DataFrame(data, columns=['date', 'temp_aoi_mean'])

# %%
# convert temp from K to C
df['temp_C'] = df['temp_aoi_mean'] - 273.15

# %%
# save csv 
df.to_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia_temp.csv')

# %% [markdown]
# load temperature data csv and plot

# %%
temp = pd.read_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia_temp.csv')

# %%
# convert date to datetime
temp['date'] = pd.to_datetime(temp['date'])

# add ordinal date column to assist with plotting
temp['date_ordinal'] = temp['date'].apply(lambda x: x.toordinal())

temp['doy'] = temp['date'].dt.dayofyear
temp['year'] = temp['date'].dt.year

# %% [markdown]
# Plot Inverse and Normal greening NDVIs over time with Temperature

# %%
fig, ax1 = plt.subplots(figsize=(9,5))

# WT ndvi
inverse[inverse['region'] == 'track'].plot.scatter(x='date', y='ndvi_mean', color='blue', label='Water Track', ax=ax1)

# Intertack ndvi
inverse[inverse['region'] == 'intertrack'].plot.scatter(x='date', y='ndvi_mean', color='green', label='Intertrack', ax=ax1)

ax1.set_xlabel('Date')
ax1.set_ylabel('Mean NDVI')
ax1.set_xlim(pd.to_datetime('2019-01-01'), pd.to_datetime('2024-01-01'))

# temperature y axis
ax2 = ax1.twinx()

ax2.plot(temp['date'], temp['temp_C'], color='red', label='Temperature', linestyle='-', alpha=0.2)
# ax2.fill_between(temp['date'], temp['temp_C'],temp['temp_C'].min(), color='red', alpha=0.2)

ax2.set_ylabel('Temperature (°C)')

# legend
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
handles = handles1 + handles2
labels = labels1 + labels2

ax1.legend(handles, labels, bbox_to_anchor=(0.5, -0.15), loc='center', ncol = 3, frameon = False)

# plt.title('Mean MaxNDVI of Inverse Greening Water Track and Intertrack')

fig.tight_layout()
plt.show()

# %% [markdown]
# plot temp deviation from DOY average

# %%
temp_mean = temp.groupby(['doy']).mean().reset_index()

# %%
temp_mean.rename(columns = {'temp_C':'doy_temp_mean'}, inplace = True)

# %%
temp = temp.merge(temp_mean[['doy', 'doy_temp_mean']], on='doy', how='left')

# %%
temp['doy_temp_mean_var'] = temp['temp_C'] - temp['doy_temp_mean']

# %%
fig, ax1 = plt.subplots(figsize=(9,6))

# WT ndvi
inverse[inverse['region'] == 'track'].plot.scatter(x='date', y='ndvi_mean', color='blue', label='Water Track', ax=ax1)

# Intertack ndvi
inverse[inverse['region'] == 'intertrack'].plot.scatter(x='date', y='ndvi_mean', color='green', label='Intertrack', ax=ax1)

ax1.set_xlabel('Date')
ax1.set_ylabel('Mean NDVI')
ax1.set_xlim(pd.to_datetime('2019-01-01'), pd.to_datetime('2024-01-01'))

# temperature y axis
ax2 = ax1.twinx()

ax2.plot(temp['date'], temp['doy_temp_mean_var'], color='red', label='Temperature Difference', linestyle='-', alpha=0.2)
#ax2.fill_between(temp['date'], temp['doy_temp_mean_var'],temp['doy_temp_mean_var'].min(), color='red', alpha=0.2)

ax2.set_ylabel('Departure from 2019-2024 DOY Mean Temperature (°C)')

# legend
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
handles = handles1 + handles2
labels = labels1 + labels2

ax1.legend(handles, labels, bbox_to_anchor=(0.5, -0.15), loc='center', ncol = 3, frameon = False)

plt.title('Mean MaxNDVI of Inverse Greening Water Track and Intertrack')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Create image collection and DF of other climate data

# %%
band_name = 'sub_surface_runoff_sum'
# 'soil_temperature_level_1','snow_cover','volumetric_soil_water_layer_1' ]

# set average (from band) over aoi as a property
climate_collection = dataset.map(mean_stat)

climate_features = climate_collection.map(
    lambda image: ee.Feature(None, {
        'date': image.date().format('YYYY-MM-dd'),
        band_name+'_aoi_mean': image.get(band_name+'_aoi_mean')
    })
).getInfo()

data = []

# add date and temp_aoi_mean to data frame
for feature in climate_features['features']:
    properties = feature['properties']
    # print(properties)
    data.append({
            'date': properties['date'],
            band_name+'_aoi_mean': properties[band_name+'_aoi_mean']
        })
    
df = pd.DataFrame(data, columns=['date', band_name+'_aoi_mean'])

# %%
# save csv 
df.to_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia_SubRunoff.csv')

# %% [markdown]
# plot

# %%
climate_df = pd.read_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/ESiberia_SubRunoff.csv')

# %%
# convert date to datetime
climate_df['date'] = pd.to_datetime(climate_df['date'])

# add ordinal date column to assist with plotting
climate_df['date_ordinal'] = climate_df['date'].apply(lambda x: x.toordinal())

climate_df['doy'] = climate_df['date'].dt.dayofyear
climate_df['year'] = climate_df['date'].dt.year

# %%
fig, ax1 = plt.subplots(figsize=(9,6))

# WT ndvi
inverse[inverse['region'] == 'track'].plot.scatter(x='date', y='ndvi_mean', color='blue', label='Water Track', ax=ax1)

# Intertack ndvi
inverse[inverse['region'] == 'intertrack'].plot.scatter(x='date', y='ndvi_mean', color='green', label='Intertrack', ax=ax1)

ax1.set_xlabel('Date')
ax1.set_ylabel('Mean NDVI')
ax1.set_xlim(pd.to_datetime('2019-01-01'), pd.to_datetime('2024-01-01'))

# temperature y axis
ax2 = ax1.twinx()

ax2.plot(climate_df['date'], climate_df['sub_surface_runoff_sum_aoi_mean'], color='red', label='Sub-surface Runoff (m)', linestyle='-', alpha=0.3)
# ax2.fill_between(temp['date'], temp['temp_C'],temp['temp_C'].min(), color='red', alpha=0.2)

ax2.set_ylabel('Sub-surface Runoff (m)')

# legend
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
handles = handles1 + handles2
labels = labels1 + labels2

ax1.legend(handles, labels, bbox_to_anchor=(0.5, -0.15), loc='center', ncol = 3, frameon = False)

plt.title('Mean MaxNDVI of Inverse Greening Water Track and Intertrack')

fig.tight_layout()
plt.show()

# %% [markdown]
# # K Means Clustering

# %% [markdown]
# Make an image with June Greeness, Greening Season Trend, Interannual greening trend, and Trend of Trend as bands

# %%
# pick the image with the most coverage

trend_image = dataset.sort('NODATA_PIXEL_PERCENTAGE', False).first().select('B4', 'B3', 'B2')

# %%
# trend of trend
# yearwise_trend = years.map(annual_trend)

# for item in yearwise_trend.getInfo():
#     print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

# yearCompCol = ee.ImageCollection.fromImages(yearwise_trend)

# trend = yearCompCol.reduce(ee.Reducer.linearFit())

# scale = trend.select('scale')

# trend_image = trend_image.addBands(scale.rename('trend'))

# %%
# calculate mean growing season trend 2019-2023

trend = yearCompCol.reduce(ee.Reducer.mean())

scale = trend.select('scale_mean')

trend_image = trend_image.addBands(scale.rename('season'))

# %%
# temporal - calculate change in annual max ndvi over time

yearwise_ndvi = years.map(annual_images)

for item in yearwise_ndvi.getInfo():
    print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

yearCompCol = ee.ImageCollection.fromImages(yearwise_ndvi)

trend = yearCompCol.select(['system:time_start_mean',
                            'NDVI_max'
                             ]).reduce(ee.Reducer.linearFit())

scale = trend.select('scale')
    
trend_image = trend_image.addBands(scale.rename('temporal'))

# %%
# calculate June Greenness 2019-2023

end_month = 6

yearwise_ndvi = years.map(annual_images)

for item in yearwise_ndvi.getInfo():
    print("Year:", item['properties']['year'], "Number of images:", item['properties']['num'])

yearCompCol = ee.ImageCollection.fromImages(yearwise_ndvi)

# Get linear fit to pixelwise trend of annual max NDVI
trend = yearCompCol.select(['system:time_start_mean',
                                    f'{index}_{analysis}'
                                    ]).reduce(ee.Reducer.linearFit())
    
scale = trend.select('scale')
    
trend_image = trend_image.addBands(scale.rename('june'))

# %% [markdown]
# training

# %%
img = trend_image.select('temporal', 'june','season' )

training = img.sample(
    region=aoi,
    scale=10,
    numPixels=5000
)

# %% [markdown]
# kmeans

# %%
kmeans = ee.Clusterer.wekaKMeans(3).train(training) # integer = number of clusters

kmeansresult = img.cluster(kmeans)

# %%
# plot RGB
Map.addLayer(trend_image.select('B4', 'B3', 'B2'), {'min': 0.0, 'max': 0.3}, ee.Image(trend_image).date().format('yyyy-MM-dd').getInfo(), True)

# plot clusters
Map.addLayer(kmeansresult.select('cluster'),
              {'min':0, 'max':3,
               # 'palette': cm.palettes.viridis
            },
 'kmeans')

Map

# %%
geemap.download_ee_image(kmeansresult, str('tgc3b_kmeans.tif'), scale=10, region=aoi.geometry(), crs='EPSG:3995')

# %% [markdown]
# plots

# %%
# convert to df

sample = kmeansresult.addBands(trend_image.select('temporal','june')).sample(
    region=aoi,
    scale=10,
    numPixels=5000
).getInfo()

data = []

for feature in sample['features']:
    properties = feature['properties']
    data.append([properties['june'], properties['temporal'], properties['cluster']])
df = pd.DataFrame(data, columns=['temporal', 'june', 'cluster'])

# %%
# save csv 
df.to_csv('/sciclone/home/aekastning/pycogss_recipes/spectral-change-detector/output/tgc3b_kmeans_june-temporal.csv')

# %%
# 3d plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# scatter = ax.scatter(df['temporal'], df['season'], df['june'], c=df['cluster'], cmap='gray')

# # Labels
# ax.set_xlabel('temporal')
# ax.set_ylabel('season')
# ax.set_zlabel('june')

# # Legend
# legend1 = ax.legend(*scatter.legend_elements(), title="clusters")
# ax.add_artist(legend1)

# # Show plot
# plt.show()

# %%
# 2 variables
fig = plt.figure()

scatter = plt.scatter(df['temporal'], df['june'], c=df['cluster'], cmap='gray', edgecolors='k')

# Labels
plt.xlabel('temporal')
plt.ylabel('june')

# Legend
legend1 = plt.legend(*scatter.legend_elements(), title="Clusters")

# Show plot
plt.show()

# %%
sns.catplot(kind='box', data=df, y='june', x='cluster', palette="gray")
plt.tight_layout()
plt.show()

# %%
sns.catplot(kind='box', data=df, y='temporal', x='cluster', palette="gray")
plt.tight_layout()
plt.show()
